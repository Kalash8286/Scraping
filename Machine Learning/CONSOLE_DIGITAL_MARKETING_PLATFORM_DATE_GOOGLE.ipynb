# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalash8286/Scraping/blob/main/Machine%20Learning/CONSOLE_DIGITAL_MARKETING_PLATFORM_DATE_GOOGLE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt

# %%
datasetDate = pd.read_csv("CONSOLE_DIGITAL_MARKETING_PLATFORM_DATE_GOOGLE.csv", sep=",")
dataset = datasetDate.loc[:, datasetDate.columns != 'DATE']

# %%
print(datasetDate.columns)
print(dataset.columns)
# Out:
# Index(['DATE', 'FACEBOOK', 'INSTAGRAM', 'TWITTER', 'QUORA', 'LINKEDIN',
#        'REDDIT', 'SNAPCHAT', 'YOUTUBE', 'TIKTOK', 'EMAIL', 'OTHER'],
#       dtype='object')
# Index(['FACEBOOK', 'INSTAGRAM', 'TWITTER', 'QUORA', 'LINKEDIN', 'REDDIT',
#        'SNAPCHAT', 'YOUTUBE', 'TIKTOK', 'EMAIL', 'OTHER'],
#       dtype='object')

# %%
print(dataset.shape)
# Out:
# (320, 11)

# %%
dataset.head(5)
# Out:
#    FACEBOOK  INSTAGRAM  TWITTER  QUORA  LINKEDIN  REDDIT  SNAPCHAT  YOUTUBE  \
# 0         2          0        0      0         3      35         4        0
# 1       116          1        0      0         0      18         2        0
# 2        10          6        0      0         5      31         5        0
# 3        39          0        1      0         1      70         2        0
# 4        77         17        0      0         5      18         0        0
#
#    TIKTOK  EMAIL  OTHER
# 0       0      0      9
# 1       0      0      0
# 2       0      0      1
# 3       0      0      0
# 4       0      0      2

# %%
print(dataset.describe())
# Out:
#          FACEBOOK   INSTAGRAM     TWITTER       QUORA    LINKEDIN      REDDIT  \
# count  320.000000  320.000000  320.000000  320.000000  320.000000  320.000000
# mean    31.803125   11.225000   22.300000    4.196875    4.028125   22.931250
# std     43.466508   26.664865   47.128225   11.951128    7.564301   37.617964
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000    0.000000    0.000000    0.000000    0.000000    2.000000
# 50%     16.000000    1.000000    4.000000    0.000000    1.000000    8.000000
# 75%     45.250000    9.000000   27.000000    0.000000    5.000000   23.250000
# max    291.000000  169.000000  492.000000  105.000000   71.000000  246.000000
#
#          SNAPCHAT     YOUTUBE  TIKTOK       EMAIL       OTHER
# count  320.000000  320.000000   320.0  320.000000  320.000000
# mean     2.640625    2.303125     0.0    0.553125    6.175000
# std      4.171733    6.886814     0.0    2.597984   16.458573
# min      0.000000    0.000000     0.0    0.000000    0.000000
# 25%      0.000000    0.000000     0.0    0.000000    0.000000
# 50%      1.000000    0.000000     0.0    0.000000    1.000000
# 75%      3.000000    0.000000     0.0    0.000000    4.000000
# max     26.000000   47.000000     0.0   23.000000  191.000000

# %%
################## HISTOGRAM  ######################
dataset.hist(figsize=(30,25))
plt.show()

# %%
dataset.plot(figsize=(30,25))

# %%
dataset.plot.box(figsize=(30,25))

# %%
################# SUBPLOT GRAPH #####################

axs = dataset.plot.area(figsize=(30,25), subplots=True)

# %%
################# BAR GRAPH #####################

plt.figure(figsize=(150,50))

for (columnName, columnData) in dataset.iteritems():
  plt.bar(columnData.values, datasetDate.DATE, label=columnName,width=.5)

  
plt.legend()
plt.show()

# %%
################# SCATTER GRAPH #####################

plt.figure(figsize=(50,50))

for (columnName, columnData) in dataset.iteritems():
  plt.scatter(columnData.values, datasetDate.DATE, label=columnName )
  

plt.legend()
plt.show()
