# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalash8286/Scraping/blob/main/Machine%20Learning/CONSOLE_DIGITAL_MARKETING_PLATFORM_APP_GOOGLE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt

# %%
datasetDate = pd.read_csv("CONSOLE_DIGITAL_MARKETING_PLATFORM_APP_GOOGLE.csv", sep=",")
dataset = datasetDate.loc[:, datasetDate.columns != 'APP']

# %%
print(datasetDate.columns)
print(dataset.columns)
# Out:
# Index(['APP', 'FACEBOOK', 'INSTAGRAM', 'TWITTER', 'QUORA', 'LINKEDIN',
#        'REDDIT', 'SNAPCHAT', 'YOUTUBE', 'TIKTOK', 'EMAIL', 'OTHER'],
#       dtype='object')
# Index(['FACEBOOK', 'INSTAGRAM', 'TWITTER', 'QUORA', 'LINKEDIN', 'REDDIT',
#        'SNAPCHAT', 'YOUTUBE', 'TIKTOK', 'EMAIL', 'OTHER'],
#       dtype='object')

# %%
print(dataset.shape)
# Out:
# (38, 11)

# %%
dataset.head(5)
# Out:
#    FACEBOOK  INSTAGRAM  TWITTER  QUORA  LINKEDIN  REDDIT  SNAPCHAT  YOUTUBE  \
# 0       497        137      139     79        65     706        52       13
# 1       496        153      127     86        36     338        41       32
# 2       226         95      846     10        73     135        24       25
# 3       349         86      200     11        55     340         6       28
# 4       248        129      338     23        68     114        65       40
#
#    TIKTOK  EMAIL  OTHER
# 0       0      9     99
# 1       0      8    105
# 2       0      6     43
# 3       0      1     32
# 4       0     32    106

# %%
print(dataset.describe())
# Out:
#          FACEBOOK   INSTAGRAM     TWITTER      QUORA   LINKEDIN      REDDIT  \
# count   38.000000   38.000000   38.000000  38.000000  38.000000   38.000000
# mean   267.710526   94.394737  187.394737  35.342105  33.921053  193.000000
# std    163.115265   54.949874  155.838194  29.539965  23.507769  196.412143
# min      0.000000    0.000000    0.000000   1.000000   0.000000    0.000000
# 25%    123.750000   48.250000  101.250000  11.000000  16.250000   57.250000
# 50%    263.000000   90.500000  148.500000  25.500000  29.000000  126.500000
# 75%    364.500000  128.250000  222.750000  58.750000  50.500000  224.500000
# max    615.000000  297.000000  846.000000  99.000000  83.000000  772.000000
#
#         SNAPCHAT    YOUTUBE  TIKTOK      EMAIL       OTHER
# count  38.000000  38.000000    38.0  38.000000   38.000000
# mean   22.236842  19.394737     0.0   4.657895   50.868421
# std    21.002489  19.679238     0.0   6.469372   43.926333
# ...

# %%
################## HISTOGRAM  ######################
dataset.hist(figsize=(30,25))
plt.show()

# %%
dataset.plot(figsize=(30,25))

# %%
dataset.plot.box(figsize=(30,25))

# %%
################# SUBPLOT GRAPH #####################

axs = dataset.plot.area(figsize=(30,25), subplots=True)

# %%
################# BAR GRAPH #####################

plt.figure(figsize=(150,50))

for (columnName, columnData) in dataset.iteritems():
  plt.bar(columnData.values, datasetDate.APP, label=columnName,width=.5)

  
plt.legend()
plt.show()

# %%
################# SCATTER GRAPH #####################

plt.figure(figsize=(50,50))

for (columnName, columnData) in dataset.iteritems():
  plt.scatter(columnData.values, datasetDate.APP, label=columnName )
  

plt.legend()
plt.show()
