# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalash8286/Scraping/blob/main/Machine%20Learning/CONSOLE_DIGITAL_MARKETING_PLATFORM_INTERN_GOOGLE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt

# %%
datasetDate = pd.read_csv("CONSOLE_DIGITAL_MARKETING_PLATFORM_INTERN_GOOGLE.csv", sep=",")
dataset = datasetDate.loc[:, datasetDate.columns != 'INTERN']

# %%
print(datasetDate.columns)
print(dataset.columns)
# Out:
# Index(['INTERN', 'FACEBOOK', 'INSTAGRAM', 'TWITTER', 'QUORA', 'LINKEDIN',
#        'REDDIT', 'SNAPCHAT', 'YOUTUBE', 'TIKTOK', 'EMAIL', 'OTHER'],
#       dtype='object')
# Index(['FACEBOOK', 'INSTAGRAM', 'TWITTER', 'QUORA', 'LINKEDIN', 'REDDIT',
#        'SNAPCHAT', 'YOUTUBE', 'TIKTOK', 'EMAIL', 'OTHER'],
#       dtype='object')

# %%
print(dataset.shape)
# Out:
# (46, 11)

# %%
dataset.head(5)
# Out:
#    FACEBOOK  INSTAGRAM  TWITTER  QUORA  LINKEDIN  REDDIT  SNAPCHAT  YOUTUBE  \
# 0         6          4        4      0         2       2         2        0
# 1       120          2        0      0         3       2         1        0
# 2         0          0        0      0         0       0         0        0
# 3         0         48      294      0        10      76        26        0
# 4       840        186        0      0         0       0         0        0
#
#    TIKTOK  EMAIL  OTHER
# 0       0      2      2
# 1       0      0      1
# 2       0      0      0
# 3       0      0     24
# 4       0      0    500

# %%
print(dataset.describe())
# Out:
#          FACEBOOK   INSTAGRAM     TWITTER      QUORA    LINKEDIN       REDDIT  \
# count   46.000000   46.000000   46.000000  46.000000   46.000000    46.000000
# mean   132.891304   18.586957   57.739130   1.956522   10.326087   112.086957
# std    224.656897   53.124832  147.502081  13.269776   23.841192   241.090009
# min      0.000000    0.000000    0.000000   0.000000    0.000000     0.000000
# 25%      0.000000    0.000000    0.000000   0.000000    0.000000     0.000000
# 50%      2.500000    0.000000    0.000000   0.000000    0.000000    20.000000
# 75%    179.750000    4.000000   16.000000   0.000000    5.250000    79.000000
# max    858.000000  280.000000  858.000000  90.000000  122.000000  1120.000000
#
#          SNAPCHAT  YOUTUBE  TIKTOK      EMAIL       OTHER
# count   46.000000     46.0    46.0  46.000000   46.000000
# mean     4.239130      0.0     0.0   1.152174   19.717391
# std     20.679764      0.0     0.0   6.484057   76.385765
# ...

# %%
################## HISTOGRAM  ######################
dataset.hist(figsize=(30,25))
plt.show()

# %%
dataset.plot(figsize=(30,25))

# %%
dataset.plot.box(figsize=(30,25))

# %%
################# SUBPLOT GRAPH #####################

axs = dataset.plot.area(figsize=(30,25), subplots=True)

# %%
################# BAR GRAPH #####################

plt.figure(figsize=(150,50))

for (columnName, columnData) in dataset.iteritems():
  plt.bar(columnData.values, datasetDate.INTERN, label=columnName,width=.5)

  
plt.legend()
plt.show()

# %%
################# SCATTER GRAPH #####################

plt.figure(figsize=(50,50))

for (columnName, columnData) in dataset.iteritems():
  plt.scatter(columnData.values, datasetDate.INTERN, label=columnName )
  

plt.legend()
plt.show()
